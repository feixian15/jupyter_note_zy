# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import tifffile 
from PIL import Image

# %%
##直接画图
img=Image.open('/home/zy/Pictures/deep_learning/blurred.png')
plt.imshow(img)

# %%
##直接画图,改变窗口大小
img=Image.open('/home/zy/Pictures/deep_learning/blurred.png')
fig=plt.figure(figsize=(12,12))
plt.imshow(img)
##或者是：plt.imshow(img, figure=fig)

# %%
##多图显示
img=Image.open('/home/zy/Pictures/deep_learning/blurred.png')
figure=plt.figure(figsize=(14,14))
plt.subplot(2,3,1)  ##2行3列第1个图
plt.imshow(img)
plt.subplot(2,3,3)  #2行3列第3个图
plt.imshow(img)
plt.subplot(2,3,5)  #2行3列第5个图
plt.imshow(img)

# %%
img_tif=tifffile.imread('/home/feixian15/geohey/sshuair/vision-multi/sample-data/7-channel.tif')

# %%
fig=plt.figure(1,figsize=(10,10))
tifffile.imshow(img_tif[:,:,[3,2,1]],figure=fig,subplot=121)
tifffile.imshow(img_tif[:,:,[3,2,1]],figure=fig,subplot=122)
# Out:
# (<matplotlib.figure.Figure at 0x7ff920414470>,
# ...
#  <matplotlib.image.AxesImage at 0x7ff9202b8dd8>)
# (<matplotlib.figure.Figure at 0x7ff920414470>,
# ...
#  <matplotlib.image.AxesImage at 0x7ff9202897b8>)
