# %% [markdown]
# ### 以四皇后为例说明：
# ![image.png](attachment:image.png)
# 下面这个结果是错误的，因为考虑到各个皇后的顺序问题，第一个皇后可以放到任意一行（只需要放到第0行），所以出现了许多重复的结果，相当于对每一个结果做了一次全排列

# %%
all_list = []  ## 主要是解决点的重复问题，八皇后问题点是没有顺序的
def solve(n, point_list):
    if n==0 : 
        print(point_list)
        print_list= []
        for i in point_list:
            print_list.append(i[1])
        all_list.append(point_list)
    else:
        for i in range(4):
            for j in range(4):
                temp = True
                for k in point_list:
                    if i==k[0] or j==k[1] or i+j==k[0]+k[1] or j-i==k[1]-k[0]:
                        temp = False
                        break
                #if (i,j) in all_list: temp = False
                if temp: 
                    point_list.append((i,j))
                    solve(n-1,point_list)
                    point_list.pop()

# %%
(solve(4,[]))
# Out:
# [(0, 1), (1, 3), (2, 0), (3, 2)]
# [(0, 1), (1, 3), (3, 2), (2, 0)]
# [(0, 1), (2, 0), (1, 3), (3, 2)]
# [(0, 1), (2, 0), (3, 2), (1, 3)]
# [(0, 1), (3, 2), (1, 3), (2, 0)]
# [(0, 1), (3, 2), (2, 0), (1, 3)]
# [(0, 2), (1, 0), (2, 3), (3, 1)]
# [(0, 2), (1, 0), (3, 1), (2, 3)]
# [(0, 2), (2, 3), (1, 0), (3, 1)]
# [(0, 2), (2, 3), (3, 1), (1, 0)]
# [(0, 2), (3, 1), (1, 0), (2, 3)]
# [(0, 2), (3, 1), (2, 3), (1, 0)]
# [(1, 0), (0, 2), (2, 3), (3, 1)]
# [(1, 0), (0, 2), (3, 1), (2, 3)]
# [(1, 0), (2, 3), (0, 2), (3, 1)]
# [(1, 0), (2, 3), (3, 1), (0, 2)]
# [(1, 0), (3, 1), (0, 2), (2, 3)]
# [(1, 0), (3, 1), (2, 3), (0, 2)]
# [(1, 3), (0, 1), (2, 0), (3, 2)]
# [(1, 3), (0, 1), (3, 2), (2, 0)]
# [(1, 3), (2, 0), (0, 1), (3, 2)]
# [(1, 3), (2, 0), (3, 2), (0, 1)]
# [(1, 3), (3, 2), (0, 1), (2, 0)]
# [(1, 3), (3, 2), (2, 0), (0, 1)]
# [(2, 0), (0, 1), (1, 3), (3, 2)]
# [(2, 0), (0, 1), (3, 2), (1, 3)]
# [(2, 0), (1, 3), (0, 1), (3, 2)]
# [(2, 0), (1, 3), (3, 2), (0, 1)]
# ...

# %%
len(all_list)
# Out:
# 48

# %% [markdown]
# ### 这个结果才是对的

# %%
all_list = []  ## 主要是解决点的重复问题，八皇后问题点是没有顺序的
def solve(n, point_list):
    if n==0 : 
        print_list= []
        for i in point_list:
            print_list.append(i[1])
        print(print_list)
        all_list.append(point_list)
    else:
        i=8-n
        for j in range(8):
            temp = True
            for k in point_list:
                if i==k[0] or j==k[1] or i+j==k[0]+k[1] or j-i==k[1]-k[0]:
                    temp = False
                    break
            if temp: 
                point_list.append((i,j))
                solve(n-1,point_list)
                point_list.pop()

# %%
(solve(8,[]))
# Out:
# [0, 4, 7, 5, 2, 6, 1, 3]
# [0, 5, 7, 2, 6, 3, 1, 4]
# [0, 6, 3, 5, 7, 1, 4, 2]
# [0, 6, 4, 7, 1, 3, 5, 2]
# [1, 3, 5, 7, 2, 0, 6, 4]
# [1, 4, 6, 0, 2, 7, 5, 3]
# [1, 4, 6, 3, 0, 7, 5, 2]
# [1, 5, 0, 6, 3, 7, 2, 4]
# [1, 5, 7, 2, 0, 3, 6, 4]
# [1, 6, 2, 5, 7, 4, 0, 3]
# [1, 6, 4, 7, 0, 3, 5, 2]
# [1, 7, 5, 0, 2, 4, 6, 3]
# [2, 0, 6, 4, 7, 1, 3, 5]
# [2, 4, 1, 7, 0, 6, 3, 5]
# [2, 4, 1, 7, 5, 3, 6, 0]
# [2, 4, 6, 0, 3, 1, 7, 5]
# [2, 4, 7, 3, 0, 6, 1, 5]
# [2, 5, 1, 4, 7, 0, 6, 3]
# [2, 5, 1, 6, 0, 3, 7, 4]
# [2, 5, 1, 6, 4, 0, 7, 3]
# [2, 5, 3, 0, 7, 4, 6, 1]
# [2, 5, 3, 1, 7, 4, 6, 0]
# [2, 5, 7, 0, 3, 6, 4, 1]
# [2, 5, 7, 0, 4, 6, 1, 3]
# [2, 5, 7, 1, 3, 0, 6, 4]
# [2, 6, 1, 7, 4, 0, 3, 5]
# [2, 6, 1, 7, 5, 3, 0, 4]
# [2, 7, 3, 6, 0, 5, 1, 4]
# [3, 0, 4, 7, 1, 6, 2, 5]
# [3, 0, 4, 7, 5, 2, 6, 1]
# [3, 1, 4, 7, 5, 0, 2, 6]
# [3, 1, 6, 2, 5, 7, 0, 4]
# [3, 1, 6, 2, 5, 7, 4, 0]
# [3, 1, 6, 4, 0, 7, 5, 2]
# [3, 1, 7, 4, 6, 0, 2, 5]
# [3, 1, 7, 5, 0, 2, 4, 6]
# [3, 5, 0, 4, 1, 7, 2, 6]
# ...

# %%
len(all_list)
# Out:
# 92

# %% [markdown]
# 被阶乘的威力吓到

# %%
def f(n):
    if n==1 :return 1
    return n*f(n-1)

# %%
f(64)
# Out:
# 126886932185884164103433389335161480802865516174545192198801894375214704230400000000000000
